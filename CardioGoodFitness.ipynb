# %% [markdown]
# # Cardio Good Fitness
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months. The data are stored in the CardioGoodFitness.csv file.
#
# ### the variables we study:
#   - product purchased, TM195, TM498, or TM798;
#   - gender;
#   - age, in years;
#   - education, in years;
#   - relationship status, single or partnered;
#   - annual household income ;
#   - average number of times the customer plans to use the treadmill each week;
#   - average number of miles the customer expects to walk/run each week;
#   - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.

# %%
import pandas as pd
import numpy as np
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_csv('Fitness.csv')  
# load dataset

# %%
mydata.head(5) 
#show first 5 of element dataset
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
mydata.tail(5) 
#show last 5 of ewlement in dataset
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 567   TM798   32    Male         17       Married      6        5   83000
# 568   TM195   27  Female         14        Single      2        2   30000
# 569   TM498   39    Male         16       Married      4        4   70000
# 570   TM798   28    Male         18       Married      6        5   82000
# 571   TM195   20  Female         13        Single      3        3   33000
#
#      Miles
# 567    140
# 568     40
# 569     85
# 570    150
# 571     55

# %%
mydata.info()
#show columns of dataset and datatype of columns and how many data in total
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        572 non-null    object
#  1   Age            572 non-null    int64
#  2   Gender         572 non-null    object
#  3   Education      572 non-null    int64
#  4   MaritalStatus  572 non-null    object
#  5   Usage          572 non-null    int64
#  6   Fitness        572 non-null    int64
#  7   Income         572 non-null    int64
#  8   Miles          572 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 40.3+ KB

# %%
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()
#show dataset in figure

# %%
sns.boxplot(x="Gender", y="Age", data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(x="Product", y="Income", data=mydata)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
pd.crosstab(mydata['Product'],mydata['Fitness'] )
#product TM798 more professional than other
# Out:
# Fitness  1   2    3    4    5
# Product
# TM195    1  79  120    9    2
# TM498    1  12   41  132    4
# TM798    0   0    4    7  160

# %%
sns.countplot(x="Product", hue="Gender", data=mydata)
#Product TM195 often used by Females
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
mydata['Age'].mean()
mydata['Age'].std()
sns.distplot(mydata['Age'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9320\369595920.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mydata['Age'])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
mydata.hist(by='Gender',column = 'Age', figsize=(6,6))
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)
